# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# With the covid 19 impact in the market, we have seen lot of changes in the car market. Now some
# cars are in demand hence making them costly and some are not in demand hence cheaper. One
# of our clients works with small traders, who sell used cars. With the change in market due to covid
# 19 impact, our client is facing problems with their previous car price valuation machine learning
# models. So, they are looking for new machine learning models from new data. We have to make
# car price valuation model.

# %%
#Firstly we will scrape the data & will make a dataframe

# %%
#Importing the libraries

# !pip install selenium

# %% [markdown]
# # FIRST WE WILL SCRAPE THE DATA OF 5000 USED CARS & THEN WILL MERGE THE DATA INTO ONE CSV FILE

# %%
#Importing the needed libraries

import pandas as pd
import selenium
from selenium import webdriver
import warnings
warnings.filterwarnings('ignore')

# %%
#Creating an instance of the chrome driver to get to the url

driver = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver.get('https://www.olx.in/en-in/mumbai_g4058997/cars_c84?isSearchCall=false')

# %%
#Creating empty lists so that we can fetch the data

Price=[]
Year=[]
Km=[]
Company=[]
Location=[]
Date=[]

# %%
#Fetching the data from olx for Price

for p in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price.append(p.text.replace("₹","").replace(",",""))

# %%
#Printing the price

Price
# Out:
# [' 1095001',
#  ' 595000',
#  ' 475000',
#  ' 320000',
#  ' 825000',
#  ' 599000',
#  ' 395000',
#  ' 198000',
#  ' 90000',
#  ' 410000',
#  ' 999000',
#  ' 650000',
#  ' 1055000',
#  ' 949999',
#  ' 1890000',
#  ' 350000',
#  ' 394000',
#  ' 399000',
#  ' 210000',
#  ' 535000',
#  ' 295000',
#  ' 460000',
#  ' 1650000',
#  ' 600000',
#  ' 200000',
#  ' 275000',
#  ' 120000',
#  ' 33000',
#  ' 335000',
#  ' 900000',
#  ' 825000',
#  ' 435000',
#  ' 555000',
#  ' 550000',
#  ' 495000',
#  ' 725000',
#  ' 885000',
#  ' 310000',
#  ' 210000',
#  ' 1540000',
#  ' 361000',
#  ' 2650000',
#  ' 130000',
#  ' 170000',
#  ' 380000',
#  ' 230000',
#  ' 600000',
#  ' 995000',
#  ' 1175000',
#  ' 435000',
#  ' 1699999',
#  ' 650000',
#  ' 595000',
#  ' 7990000',
#  ' 2499000',
#  ' 485000',
#  ' 165000',
#  ' 12200000',
#  ' 299999',
#  ' 535000',
#  ' 849000',
#  ' 2075000',
#  ' 1290000',
#  ' 180000',
#  ' 170000',
#  ' 280000',
#  ' 1600000',
#  ' 580000',
#  ' 50000',
#  ' 264000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price)):
    Price[i] = int(Price[i])

# %%
#Printing the Price

Price
# Out:
# [1095001,
#  595000,
#  475000,
#  320000,
#  825000,
#  599000,
#  395000,
#  198000,
#  90000,
#  410000,
#  999000,
#  650000,
#  1055000,
#  949999,
#  1890000,
#  350000,
#  394000,
#  399000,
#  210000,
#  535000,
#  295000,
#  460000,
#  1650000,
#  600000,
#  200000,
#  275000,
#  120000,
#  33000,
#  335000,
#  900000,
#  825000,
#  435000,
#  555000,
#  550000,
#  495000,
#  725000,
#  885000,
#  310000,
#  210000,
#  1540000,
#  361000,
#  2650000,
#  130000,
#  170000,
#  380000,
#  230000,
#  600000,
#  995000,
#  1175000,
#  435000,
#  1699999,
#  650000,
#  595000,
#  7990000,
#  2499000,
#  485000,
#  165000,
#  12200000,
#  299999,
#  535000,
#  849000,
#  2075000,
#  1290000,
#  180000,
#  170000,
#  280000,
#  1600000,
#  580000,
#  50000,
#  264000,
#  330000,
#  105000,
#  50000,
#  575000,
#  518000,
#  350000,
#  285000,
#  210000,
#  475000,
#  865000,
#  7700000,
#  425000,
#  1425000,
#  85000,
#  780000,
#  2148000,
#  225000,
#  368000,
#  460000,
# ...

# %%
#Fetching data from olx for Year

for y in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year.append(y.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year)):
    Year[i] = int(Year[i])

# %%
#Converting year into integer type

Year
# Out:
# [2019,
#  2016,
#  2011,
#  2018,
#  2014,
#  2016,
#  2012,
#  2008,
#  2007,
#  2014,
#  2016,
#  2017,
#  2016,
#  2018,
#  2018,
#  2013,
#  2015,
#  2012,
#  2012,
#  2016,
#  2011,
#  2013,
#  2018,
#  2019,
#  2007,
#  2011,
#  2005,
#  2021,
#  2012,
#  2019,
#  2017,
#  2014,
#  2015,
#  2017,
#  1996,
#  2015,
#  2011,
#  2010,
#  2009,
#  2012,
#  2011,
#  2014,
#  2005,
#  2010,
#  2008,
#  2005,
#  2020,
#  2017,
#  2019,
#  2017,
#  2017,
#  2014,
#  2007,
#  2018,
#  2013,
#  2013,
#  2009,
#  2020,
#  2012,
#  2016,
#  2014,
#  2021,
#  2020,
#  2008,
#  2010,
#  2011,
#  2015,
#  2015,
#  2021,
#  2011,
#  2016,
#  2008,
#  2021,
#  2015,
#  2015,
#  2014,
#  2014,
#  2009,
#  2018,
#  2012,
#  2017,
#  2012,
#  2018,
#  2006,
#  2016,
#  2016,
#  2012,
#  2016,
#  2010,
#  2017,
#  2021,
#  2017,
#  2012,
#  2011,
#  2008,
#  2014,
#  2014,
#  2018,
#  2009,
#  2010,
#  2015,
#  2011,
#  2012,
#  2010,
#  2008,
#  2013,
#  2016,
#  2010,
#  2015,
#  2017,
#  2016,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km.append(k.text.split('-')[1])
for c in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company.append(c.text)
for l in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location.append(l.text)
for d in driver.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date.append(d.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS=pd.DataFrame({})
CARS['PRICE']=Price[0:500]
CARS['YEAR']=Year[0:500]
CARS['KM']=Km[0:500]
CARS['COMPANY']=Company[0:500]
CARS['LOCATION']=Location[0:500]
CARS['POSTED-DATE']=Date[0:500]

# %%
#Printing the dataframe of CARS that we have created 

CARS
# Out:
#        PRICE  YEAR           KM                      COMPANY  \
# 0    1095001  2019    18,000 km         Maruti Suzuki Ertiga
# 1     595000  2016    38,000 km                 Toyota Etios
# 2     475000  2011    67,000 km         Toyota Corolla Altis
# 3     320000  2018    90,000 km        Maruti Suzuki Wagon R
# 4     825000  2014    90,000 km         Toyota Corolla Altis
# ..       ...   ...          ...                          ...
# 495   795000  2007   136,210 km           Mitsubishi Montero
# 496   296000  2011    61,000 km                  Hyundai i10
# 497   751000  2019    12,347 km    Maruti Suzuki Swift Dzire
# 498   225000  2011   119,000 km           Maruti Suzuki Ritz
# 499   695000  2017    55,000 km  Maruti Suzuki Vitara Brezza
#
#                            LOCATION POSTED-DATE
# 0       Vile Parle East\n6 days ago  6 days ago
# 1                   Chembur\nDec 23      Dec 23
# 2                   Chembur\nDec 23      Dec 23
# ...

# %%
#Printing the information of the dataset
#Here we can see 2 columns are of integer type & others are of object datatype

CARS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
#Closing the driver

driver.close()

# %% [markdown]
# # WE HAVE SCRAPED 500 DATA FROM OLX

# %%
#Creating second instance for CHROME

driver2 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting to the website

driver2.get('https://www.olx.in/en-in/madhya-pradesh_g2001162/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_2=[]
Year_2=[]
Km_2=[]
Company_2=[]
Location_2=[]
Date_2=[]

# %%
#Fething the data from olx from Price

for p2 in driver2.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_2.append(p2.text.replace("₹","").replace(",",""))

# %%
#Printintg the Price

Price_2
# Out:
# [' 565000',
#  ' 790000',
#  ' 415000',
#  ' 115000',
#  ' 865000',
#  ' 595000',
#  ' 435000',
#  ' 140000',
#  ' 690000',
#  ' 260000',
#  ' 525000',
#  ' 1100000',
#  ' 610000',
#  ' 350000',
#  ' 625000',
#  ' 225000',
#  ' 425000',
#  ' 475000',
#  ' 250000',
#  ' 551000',
#  ' 750000',
#  ' 325000',
#  ' 425000',
#  ' 350000',
#  ' 450000',
#  ' 680000',
#  ' 325000',
#  ' 825000',
#  ' 645000',
#  ' 285000',
#  ' 380000',
#  ' 540000',
#  ' 230000',
#  ' 160000',
#  ' 200000',
#  ' 175000',
#  ' 160000',
#  ' 60000',
#  ' 325000',
#  ' 140000',
#  ' 1400000',
#  ' 725000',
#  ' 580000',
#  ' 775000',
#  ' 1050000',
#  ' 1590000',
#  ' 300000',
#  ' 125000',
#  ' 260000',
#  ' 121000',
#  ' 150000',
#  ' 130000',
#  ' 195000',
#  ' 250000',
#  ' 750000',
#  ' 355000',
#  ' 450000',
#  ' 750000',
#  ' 28000',
#  ' 450000',
#  ' 390000',
#  ' 650000',
#  ' 550000',
#  ' 350000',
#  ' 470000',
#  ' 700000',
#  ' 550000',
#  ' 675000',
#  ' 555000',
#  ' 315000',
#  ' 310000',
# ...

# %%
#Converting the datatype of the variable to int

for i in range(0, len(Price_2)):
    Price_2[i] = int(Price_2[i])

# %%
#Printing the variable after conversion

Price_2
# Out:
# [565000,
#  790000,
#  415000,
#  115000,
#  865000,
#  595000,
#  435000,
#  140000,
#  690000,
#  260000,
#  525000,
#  1100000,
#  610000,
#  350000,
#  625000,
#  225000,
#  425000,
#  475000,
#  250000,
#  551000,
#  750000,
#  325000,
#  425000,
#  350000,
#  450000,
#  680000,
#  325000,
#  825000,
#  645000,
#  285000,
#  380000,
#  540000,
#  230000,
#  160000,
#  200000,
#  175000,
#  160000,
#  60000,
#  325000,
#  140000,
#  1400000,
#  725000,
#  580000,
#  775000,
#  1050000,
#  1590000,
#  300000,
#  125000,
#  260000,
#  121000,
#  150000,
#  130000,
#  195000,
#  250000,
#  750000,
#  355000,
#  450000,
#  750000,
#  28000,
#  450000,
#  390000,
#  650000,
#  550000,
#  350000,
#  470000,
#  700000,
#  550000,
#  675000,
#  555000,
#  315000,
#  310000,
#  130000,
#  1450000,
#  270000,
#  135000,
#  510000,
#  350000,
#  110000,
#  43000,
#  354000,
#  340000,
#  700000,
#  425000,
#  355000,
#  2400000,
#  225000,
#  510000,
#  650000,
#  490000,
#  85000,
# ...

# %%
#Fetching the data from olx for Year

for y2 in driver2.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_2.append(y2.text.split('-')[0])

# %%
#Printing year 2

Year_2
# Out:
# [2013,
#  2019,
#  2014,
#  2007,
#  2018,
#  2018,
#  2014,
#  2009,
#  2018,
#  2008,
#  2015,
#  2018,
#  2013,
#  2011,
#  2015,
#  2011,
#  2014,
#  2016,
#  2010,
#  2015,
#  2017,
#  2011,
#  2017,
#  2013,
#  2014,
#  2013,
#  2015,
#  2019,
#  2018,
#  2011,
#  2014,
#  2019,
#  2014,
#  2011,
#  2010,
#  2012,
#  2010,
#  2005,
#  2017,
#  2007,
#  2013,
#  2017,
#  2016,
#  2017,
#  2018,
#  2016,
#  2011,
#  2007,
#  2008,
#  2005,
#  2006,
#  2011,
#  2010,
#  2009,
#  2018,
#  2014,
#  2013,
#  2017,
#  1999,
#  2012,
#  2012,
#  2016,
#  2018,
#  2014,
#  2014,
#  2014,
#  2015,
#  2018,
#  2017,
#  2011,
#  2010,
#  2012,
#  2016,
#  2012,
#  2010,
#  2015,
#  2018,
#  2013,
#  2000,
#  2019,
#  2007,
#  2016,
#  2012,
#  2019,
#  2017,
#  2009,
#  2014,
#  2016,
#  2015,
#  2007,
#  2015,
#  2013,
#  2020,
#  2016,
#  2010,
#  2016,
#  2017,
#  2013,
#  2012,
#  2018,
#  2012,
#  2019,
#  2013,
#  2010,
#  2019,
#  2008,
#  2015,
#  2013,
#  2011,
#  2010,
#  2012,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k2 in driver2.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_2.append(k2.text.split('-')[1])
for c2 in driver2.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_2.append(c2.text)
for l2 in driver2.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_2.append(l2.text)
for d2 in driver2.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_2.append(d2.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS2=pd.DataFrame({})
CARS2['PRICE']=Price_2[0:500]
CARS2['YEAR']=Year_2[0:500]
CARS2['KM']=Km_2[0:500]
CARS2['COMPANY']=Company_2[0:500]
CARS2['LOCATION']=Location_2[0:500]
CARS2['POSTED-DATE']=Date_2[0:500]

# %%
#Printing the datframe that we have just made

CARS2
# Out:
#      PRICE  YEAR          KM                    COMPANY  \
# 0      NaN  2013   40,000 km              Hyundai Verna
# 1      NaN  2019   39,000 km  Maruti Suzuki Swift Dzire
# 2      NaN  2014   58,990 km          Hyundai Grand i10
# 3      NaN  2007   59,000 km         Maruti Suzuki Alto
# 4      NaN  2018   65,000 km       Maruti Suzuki Ertiga
# ..     ...   ...         ...                        ...
# 495    NaN  2015   49,300 km                Skoda Rapid
# 496    NaN  2014   55,552 km        Maruti Suzuki Swift
# 497    NaN  2015   43,000 km     Maruti Suzuki Alto 800
# 498    NaN  2012   58,000 km        Maruti Suzuki Swift
# 499    NaN  2017   65,000 km          Hyundai Grand i10
#
#                                         LOCATION POSTED-DATE
# 0    Narila Shankari Chatrashal Nagar\nYesterday   Yesterday
# 1                          Bhawarkua\n4 days ago  4 days ago
# 2                                Piplani\nDec 27      Dec 27
# ...

# %%
#Getting the information for the CARS2 Dataset

CARS2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        0 non-null      float64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 23.6+ KB

# %%
#Closing the driver

driver2.close()

# %% [markdown]
# # NOW WE HAVE COLLECTED 1000 DATA

# %%
#Creating an instance of the chrome driver to get to the url

driver3 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver3.get('https://www.olx.in/en-in/maharashtra_g2001163/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_3=[]
Year_3=[]
Km_3=[]
Company_3=[]
Location_3=[]
Date_3=[]

# %%
#Fetching the data from olx for Price

for p3 in driver3.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_3.append(p3.text.replace("₹","").replace(",",""))

# %%
#Printing the price

Price_3
# Out:
# [' 575000',
#  ' 125000',
#  ' 1050000',
#  ' 150000',
#  ' 550000',
#  ' 350000',
#  ' 279000',
#  ' 155000',
#  ' 575000',
#  ' 545000',
#  ' 545000',
#  ' 774000',
#  ' 1750000',
#  ' 1375000',
#  ' 90000',
#  ' 1375000',
#  ' 395000',
#  ' 450000',
#  ' 1285000',
#  ' 155000',
#  ' 1399000',
#  ' 925000',
#  ' 1851000',
#  ' 275000',
#  ' 170000',
#  ' 495000',
#  ' 1829000',
#  ' 275000',
#  ' 145000',
#  ' 515000',
#  ' 290000',
#  ' 246000',
#  ' 274000',
#  ' 235000',
#  ' 2875000',
#  ' 495000',
#  ' 335000',
#  ' 525000',
#  ' 695000',
#  ' 485000',
#  ' 211000',
#  ' 575000',
#  ' 241000',
#  ' 390000',
#  ' 310000',
#  ' 635000',
#  ' 725000',
#  ' 425000',
#  ' 415000',
#  ' 260000',
#  ' 540000',
#  ' 210000',
#  ' 210000',
#  ' 1350000',
#  ' 490000',
#  ' 200000',
#  ' 300000',
#  ' 235000',
#  ' 75000',
#  ' 260000',
#  ' 1295000',
#  ' 850000',
#  ' 1400000',
#  ' 140000',
#  ' 100000',
#  ' 215000',
#  ' 389999',
#  ' 1590000',
#  ' 1405000',
#  ' 271000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_3)):
    Price_3[i] = int(Price_3[i])

# %%
#Printing aftewr conversion

Price_3
# Out:
# [575000,
#  125000,
#  1050000,
#  150000,
#  550000,
#  350000,
#  279000,
#  155000,
#  575000,
#  545000,
#  545000,
#  774000,
#  1750000,
#  1375000,
#  90000,
#  1375000,
#  395000,
#  450000,
#  1285000,
#  155000,
#  1399000,
#  925000,
#  1851000,
#  275000,
#  170000,
#  495000,
#  1829000,
#  275000,
#  145000,
#  515000,
#  290000,
#  246000,
#  274000,
#  235000,
#  2875000,
#  495000,
#  335000,
#  525000,
#  695000,
#  485000,
#  211000,
#  575000,
#  241000,
#  390000,
#  310000,
#  635000,
#  725000,
#  425000,
#  415000,
#  260000,
#  540000,
#  210000,
#  210000,
#  1350000,
#  490000,
#  200000,
#  300000,
#  235000,
#  75000,
#  260000,
#  1295000,
#  850000,
#  1400000,
#  140000,
#  100000,
#  215000,
#  389999,
#  1590000,
#  1405000,
#  271000,
#  135000,
#  360000,
#  611000,
#  225000,
#  365000,
#  421000,
#  950000,
#  90000,
#  245000,
#  225000,
#  455000,
#  310000,
#  799999,
#  210000,
#  200000,
#  236000,
#  675000,
#  785000,
#  120000,
# ...

# %%
#Fetching data from olx for Year

for y3 in driver3.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_3.append(y3.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_3)):
    Year_3[i] = int(Year_3[i])

# %%
#Printing after conversion

Year_3
# Out:
# [2014,
#  2007,
#  2015,
#  2016,
#  2018,
#  2018,
#  2014,
#  2008,
#  2014,
#  2015,
#  2012,
#  2011,
#  2014,
#  2013,
#  2021,
#  2013,
#  2013,
#  2013,
#  2012,
#  2009,
#  2018,
#  2018,
#  2013,
#  2017,
#  2016,
#  2017,
#  2019,
#  2013,
#  2011,
#  2014,
#  2014,
#  2012,
#  2010,
#  2011,
#  2016,
#  2017,
#  2016,
#  2014,
#  2016,
#  2018,
#  2011,
#  2010,
#  2011,
#  2018,
#  2012,
#  2018,
#  2016,
#  2010,
#  2016,
#  2010,
#  2014,
#  2010,
#  2009,
#  2017,
#  2013,
#  2021,
#  2021,
#  2009,
#  2015,
#  2009,
#  2016,
#  2013,
#  2019,
#  2015,
#  2011,
#  2010,
#  2015,
#  2014,
#  2018,
#  2010,
#  2008,
#  2010,
#  2016,
#  2008,
#  2011,
#  2012,
#  2015,
#  2005,
#  2010,
#  2011,
#  2016,
#  2010,
#  2014,
#  2009,
#  2009,
#  2010,
#  2018,
#  2017,
#  2015,
#  2012,
#  2012,
#  2010,
#  2019,
#  2010,
#  2008,
#  2017,
#  2017,
#  2012,
#  2016,
#  2015,
#  2007,
#  2013,
#  2015,
#  2010,
#  2006,
#  2008,
#  2013,
#  2011,
#  2011,
#  2013,
#  2011,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k3 in driver3.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_3.append(k3.text.split('-')[1])
for c3 in driver3.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_3.append(c3.text)
for l3 in driver3.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_3.append(l3.text)
for d3 in driver3.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_3.append(d3.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS3=pd.DataFrame({})
CARS3['PRICE']=Price_3[0:500]
CARS3['YEAR']=Year_3[0:500]
CARS3['KM']=Km_3[0:500]
CARS3['COMPANY']=Company_3[0:500]
CARS3['LOCATION']=Location_3[0:500]
CARS3['POSTED-DATE']=Date_3[0:500]

# %%
#Printing the dataframe

CARS3
# Out:
#        PRICE  YEAR          KM                 COMPANY               LOCATION  \
# 0     575000  2014   86,000 km          Renault Duster    Satpur MIDC\nJan 12
# 1     125000  2007   55,000 km      Maruti Suzuki Alto  Yewlekar Mala\nDec 17
# 2    1050000  2015   65,000 km           Toyota Innova   Dombivli\n2 days ago
# 3     150000  2016   70,000 km              Nissan GTR      Naro Nagar\nToday
# 4     550000  2018   20,000 km  Mahindra Bolero Pik-Up          Vazira\nToday
# ..       ...   ...         ...                     ...                    ...
# 493   279000  2012   49,407 km             Hyundai i10     Mulund West\nToday
# 494   289000  2015       30 km            Renault KWID     Mulund West\nToday
# 495   249000  2014   87,986 km  Maruti Suzuki Alto 800     Mulund West\nToday
# 496   399000  2014   56,665 km       Hyundai Grand i10     Mulund West\nToday
# 497  1299000  2019   35,000 km           Hyundai Creta        Kharghar\nToday
#
#     POSTED-DATE
# ...

# %%
#Getting the information about the dataset

CARS3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        498 non-null    int64
#  1   YEAR         498 non-null    int64
#  2   KM           498 non-null    object
#  3   COMPANY      498 non-null    object
#  4   LOCATION     498 non-null    object
#  5   POSTED-DATE  498 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.5+ KB

# %%
#Closing the driver3

driver3.close()

# %% [markdown]
# # 1498 DATA COLLECTED NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver4 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver4.get('https://www.olx.in/en-in/gujarat_g2001154/cars_c84?isSearchCall=false')

# %%
#Creating empty lists so that we can fetch the data

Price_4=[]
Year_4=[]
Km_4=[]
Company_4=[]
Location_4=[]
Date_4=[]

# %%
#Fetching the data from olx for Price

for p4 in driver4.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_4.append(p4.text.replace("₹","").replace(",",""))

# %%
#Printing the price

Price_4
# Out:
# [' 575000',
#  ' 265000',
#  ' 215000',
#  ' 155000',
#  ' 540000',
#  ' 168000',
#  ' 595000',
#  ' 450000',
#  ' 440000',
#  ' 325000',
#  ' 325000',
#  ' 1850000',
#  ' 745000',
#  ' 1575000',
#  ' 225000',
#  ' 575000',
#  ' 251000',
#  ' 115000',
#  ' 450000',
#  ' 3751000',
#  ' 825000',
#  ' 620000',
#  ' 665000',
#  ' 950000',
#  ' 877000',
#  ' 145000',
#  ' 1280000',
#  ' 950000',
#  ' 385000',
#  ' 325000',
#  ' 125000',
#  ' 480000',
#  ' 675000',
#  ' 210000',
#  ' 560000',
#  ' 145000',
#  ' 265000',
#  ' 339000',
#  ' 270000',
#  ' 195000',
#  ' 298000',
#  ' 325000',
#  ' 235000',
#  ' 150000',
#  ' 1250000',
#  ' 425000',
#  ' 280000',
#  ' 565000',
#  ' 255000',
#  ' 125000',
#  ' 260000',
#  ' 2151000',
#  ' 365000',
#  ' 225000',
#  ' 150000',
#  ' 550000',
#  ' 650000',
#  ' 625000',
#  ' 890000',
#  ' 155000',
#  ' 165000',
#  ' 471000',
#  ' 290000',
#  ' 500000',
#  ' 235000',
#  ' 291000',
#  ' 851000',
#  ' 475000',
#  ' 475001',
#  ' 250000',
#  ' 350000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_4)):
    Price_4[i] = int(Price_4[i])

# %%
#Printing after conversion

Price_4
# Out:
# [575000,
#  265000,
#  215000,
#  155000,
#  540000,
#  168000,
#  595000,
#  450000,
#  440000,
#  325000,
#  325000,
#  1850000,
#  745000,
#  1575000,
#  225000,
#  575000,
#  251000,
#  115000,
#  450000,
#  3751000,
#  825000,
#  620000,
#  665000,
#  950000,
#  877000,
#  145000,
#  1280000,
#  950000,
#  385000,
#  325000,
#  125000,
#  480000,
#  675000,
#  210000,
#  560000,
#  145000,
#  265000,
#  339000,
#  270000,
#  195000,
#  298000,
#  325000,
#  235000,
#  150000,
#  1250000,
#  425000,
#  280000,
#  565000,
#  255000,
#  125000,
#  260000,
#  2151000,
#  365000,
#  225000,
#  150000,
#  550000,
#  650000,
#  625000,
#  890000,
#  155000,
#  165000,
#  471000,
#  290000,
#  500000,
#  235000,
#  291000,
#  851000,
#  475000,
#  475001,
#  250000,
#  350000,
#  681000,
#  325000,
#  230000,
#  275000,
#  690000,
#  300000,
#  790000,
#  1300000,
#  1650000,
#  575000,
#  285000,
#  3900000,
#  111500,
#  350000,
#  211000,
#  145000,
#  315000,
#  965000,
#  141000,
# ...

# %%
#Fetching data from olx for Year

for y4 in driver4.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_4.append(y4.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_4)):
    Year_4[i] = int(Year_4[i])

# %%
#Printing after conversion

Year_4
# Out:
# [2014,
#  2013,
#  2014,
#  2007,
#  2012,
#  2001,
#  2018,
#  2020,
#  2015,
#  2013,
#  2013,
#  2013,
#  2020,
#  2017,
#  2010,
#  2015,
#  2012,
#  2010,
#  2019,
#  2018,
#  2015,
#  2016,
#  2016,
#  2016,
#  2015,
#  2007,
#  2014,
#  2016,
#  2009,
#  2018,
#  2007,
#  2016,
#  2018,
#  2010,
#  2017,
#  2009,
#  2013,
#  2013,
#  2011,
#  2010,
#  2013,
#  2012,
#  2010,
#  2012,
#  2020,
#  2014,
#  2019,
#  2015,
#  2008,
#  2006,
#  2016,
#  2017,
#  1913,
#  2014,
#  2007,
#  2012,
#  2015,
#  2015,
#  2017,
#  2006,
#  2009,
#  2012,
#  2014,
#  2020,
#  2005,
#  2011,
#  2015,
#  2013,
#  2013,
#  2004,
#  2019,
#  2012,
#  2016,
#  2012,
#  2011,
#  2013,
#  2011,
#  2016,
#  2018,
#  2016,
#  2015,
#  2017,
#  2017,
#  1990,
#  2013,
#  2011,
#  2008,
#  2012,
#  2017,
#  2009,
#  2019,
#  2020,
#  2018,
#  2014,
#  2005,
#  2015,
#  2013,
#  2019,
#  2014,
#  2013,
#  2015,
#  2010,
#  2007,
#  2018,
#  2017,
#  2011,
#  2021,
#  2019,
#  2016,
#  2018,
#  2017,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k4 in driver4.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_4.append(k4.text.split('-')[1])
for c4 in driver4.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_4.append(c4.text)
for l4 in driver4.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_4.append(l4.text)
for d4 in driver4.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_4.append(d4.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS4=pd.DataFrame({})
CARS4['PRICE']=Price_4[0:500]
CARS4['YEAR']=Year_4[0:500]
CARS4['KM']=Km_4[0:500]
CARS4['COMPANY']=Company_4[0:500]
CARS4['LOCATION']=Location_4[0:500]
CARS4['POSTED-DATE']=Date_4[0:500]

# %%
#Printing the dataframe

CARS4
# Out:
#        PRICE  YEAR           KM                 COMPANY  \
# 0     575000  2014   128,000 km         Hyundai Elantra
# 1     265000  2013    85,000 km      Maruti Suzuki Ritz
# 2     215000  2014    68,150 km  Maruti Suzuki Alto K10
# 3     155000  2007    90,000 km          Hyundai Santro
# 4     540000  2012   180,700 km       Volkswagen Passat
# ..       ...   ...          ...                     ...
# 495   160000  2006    58,000 km   Maruti Suzuki Wagon R
# 496   540000  2015    81,000 km        Mahindra TUV 300
# 497   495000  2015    27,500 km     Maruti Suzuki Swift
# 498  1150000  2018    65,000 km            Jeep Compass
# 499   499000  2012    82,000 km         Mahindra XUV500
#
#                      LOCATION POSTED-DATE
# 0              Vadsar\nDec 28      Dec 28
# 1          SG Highway\nJan 07      Jan 07
# 2              Vadsar\nJan 02      Jan 02
# 3        Hussain Tekri\nToday       Today
# 4    Korecha Nagar\nYesterday   Yesterday
# ...

# %%
#Getting the information of the dataset

CARS4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
driver4.close()

# %% [markdown]
# # 1998 DATA IS WE HAVE ALL IN NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver5 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver5.get('https://www.olx.in/en-in/tamil-nadu_g2001173/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_5=[]
Year_5=[]
Km_5=[]
Company_5=[]
Location_5=[]
Date_5=[]

# %%
#Fetching the data from olx for Price

for p5 in driver5.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_5.append(p5.text.replace("₹","").replace(",",""))

# %%
#Printing the price

Price_5
# Out:
# [' 325000',
#  ' 265000',
#  ' 515000',
#  ' 275000',
#  ' 33000',
#  ' 410000',
#  ' 20000',
#  ' 455000',
#  ' 400000',
#  ' 2850000',
#  ' 249000',
#  ' 210000',
#  ' 4990000',
#  ' 420000',
#  ' 465000',
#  ' 525000',
#  ' 220000',
#  ' 290000',
#  ' 645000',
#  ' 390000',
#  ' 1950000',
#  ' 400000',
#  ' 450000',
#  ' 465000',
#  ' 815000',
#  ' 465000',
#  ' 690000',
#  ' 295000',
#  ' 295000',
#  ' 400000',
#  ' 630000',
#  ' 220000',
#  ' 220000',
#  ' 630000',
#  ' 1550000',
#  ' 450000',
#  ' 425000',
#  ' 660000',
#  ' 600000',
#  ' 435000',
#  ' 520000',
#  ' 1900000',
#  ' 750000',
#  ' 390000',
#  ' 390000',
#  ' 535000',
#  ' 450000',
#  ' 575000',
#  ' 325000',
#  ' 680000',
#  ' 565000',
#  ' 435000',
#  ' 525000',
#  ' 695000',
#  ' 615000',
#  ' 535000',
#  ' 415000',
#  ' 425000',
#  ' 435000',
#  ' 795000',
#  ' 925000',
#  ' 175000',
#  ' 740000',
#  ' 525000',
#  ' 485000',
#  ' 1825000',
#  ' 48000',
#  ' 475000',
#  ' 325000',
#  ' 390000',
#  ' 80000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_5)):
    Price_5[i] = int(Price_5[i])

# %%
#Printing after conversion

Price_5
# Out:
# [325000,
#  265000,
#  515000,
#  275000,
#  33000,
#  410000,
#  20000,
#  455000,
#  400000,
#  2850000,
#  249000,
#  210000,
#  4990000,
#  420000,
#  465000,
#  525000,
#  220000,
#  290000,
#  645000,
#  390000,
#  1950000,
#  400000,
#  450000,
#  465000,
#  815000,
#  465000,
#  690000,
#  295000,
#  295000,
#  400000,
#  630000,
#  220000,
#  220000,
#  630000,
#  1550000,
#  450000,
#  425000,
#  660000,
#  600000,
#  435000,
#  520000,
#  1900000,
#  750000,
#  390000,
#  390000,
#  535000,
#  450000,
#  575000,
#  325000,
#  680000,
#  565000,
#  435000,
#  525000,
#  695000,
#  615000,
#  535000,
#  415000,
#  425000,
#  435000,
#  795000,
#  925000,
#  175000,
#  740000,
#  525000,
#  485000,
#  1825000,
#  48000,
#  475000,
#  325000,
#  390000,
#  80000,
#  595000,
#  575000,
#  490000,
#  370000,
#  240000,
#  500000,
#  340000,
#  130000,
#  2700000,
#  575000,
#  350000,
#  850000,
#  950000,
#  180999,
#  285000,
#  285000,
#  800000,
#  1850000,
#  1150000,
# ...

# %%
#Fetching data from olx for Year

for y5 in driver5.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_5.append(y5.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_5)):
    Year_5[i] = int(Year_5[i])

# %%
#Printing after conversion

Year_5
# Out:
# [2011,
#  2009,
#  2015,
#  2012,
#  1997,
#  2013,
#  2014,
#  2013,
#  2007,
#  2018,
#  2010,
#  2009,
#  2016,
#  2011,
#  2014,
#  2014,
#  2003,
#  2013,
#  2015,
#  2011,
#  2017,
#  2012,
#  2013,
#  2013,
#  2018,
#  2011,
#  2015,
#  2017,
#  2013,
#  2010,
#  2019,
#  2017,
#  2017,
#  2019,
#  2014,
#  2012,
#  2009,
#  2018,
#  2018,
#  2008,
#  2018,
#  2017,
#  2008,
#  2011,
#  2011,
#  2015,
#  2016,
#  2014,
#  2018,
#  2017,
#  2016,
#  2015,
#  2019,
#  2016,
#  2016,
#  2012,
#  2014,
#  2011,
#  2015,
#  2016,
#  2014,
#  2012,
#  2014,
#  2016,
#  2014,
#  2017,
#  1998,
#  2013,
#  2017,
#  2014,
#  2004,
#  2019,
#  2019,
#  2010,
#  2009,
#  2012,
#  2018,
#  2012,
#  2006,
#  2014,
#  2016,
#  2006,
#  2018,
#  2019,
#  2006,
#  2012,
#  2009,
#  2011,
#  2018,
#  2019,
#  2019,
#  2017,
#  2019,
#  2013,
#  2015,
#  2014,
#  2014,
#  2012,
#  2017,
#  2016,
#  2014,
#  2009,
#  2019,
#  2018,
#  2014,
#  2012,
#  2010,
#  2008,
#  2008,
#  2013,
#  2013,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k5 in driver5.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_5.append(k5.text.split('-')[1])
for c5 in driver5.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_5.append(c5.text)
for l5 in driver5.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_5.append(l5.text)
for d5 in driver5.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_5.append(d5.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS5=pd.DataFrame({})
CARS5['PRICE']=Price_5[0:500]
CARS5['YEAR']=Year_5[0:500]
CARS5['KM']=Km_5[0:500]
CARS5['COMPANY']=Company_5[0:500]
CARS5['LOCATION']=Location_5[0:500]
CARS5['POSTED-DATE']=Date_5[0:500]

# %%
#Printing the dataframe

CARS5
# Out:
#       PRICE  YEAR           KM                 COMPANY  \
# 0    325000  2011    48,530 km              Honda Brio
# 1    265000  2009   100,000 km             Hyundai i10
# 2    515000  2015    41,000 km           Hyundai Xcent
# 3    275000  2012    30,000 km  Chevrolet Optra Magnum
# 4     33000  1997    10,000 km       Maruti Suzuki Zen
# ..      ...   ...          ...                     ...
# 495  300000  2010    54,800 km             Hyundai i10
# 496  740000  2014   135,000 km        Volkswagen Jetta
# 497  310000  2011    80,000 km             Hyundai i10
# 498  420000  2018   130,000 km               Tata Zest
# 499  445000  2014    67,000 km           Hyundai Xcent
#
#                                 LOCATION POSTED-DATE
# 0                 Tatabad Colony\nNov 25      Nov 25
# 1                       RS Puram\nJan 10      Jan 10
# 2                       Goldwins\nOct 16      Oct 16
# 3            Chennai Central\n2 days ago  2 days ago
# ...

# %%
#Getting the information of the dataset

CARS5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
driver5.close()

# %% [markdown]
# # 2498 IN TOTAL NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver6 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver6.get('https://www.olx.in/en-in/chennai_g4059162/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_6=[]
Year_6=[]
Km_6=[]
Company_6=[]
Location_6=[]
Date_6=[]

# %%
#Fetching the data from olx for Price

for p6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_6.append(p6.text.replace("₹","").replace(",",""))

# %%
Price_6
# Out:
# [' 6800000',
#  ' 710000',
#  ' 775000',
#  ' 275000',
#  ' 350000',
#  ' 295000',
#  ' 410000',
#  ' 249000',
#  ' 210000',
#  ' 420000',
#  ' 465000',
#  ' 220000',
#  ' 645000',
#  ' 390000',
#  ' 465000',
#  ' 690000',
#  ' 600000',
#  ' 265000',
#  ' 174000',
#  ' 170000',
#  ' 950000',
#  ' 700000',
#  ' 4400000',
#  ' 263000',
#  ' 155000',
#  ' 355000',
#  ' 225000',
#  ' 1450000',
#  ' 615000',
#  ' 535000',
#  ' 415000',
#  ' 425000',
#  ' 435000',
#  ' 795000',
#  ' 525000',
#  ' 485000',
#  ' 325000',
#  ' 390000',
#  ' 490000',
#  ' 230000',
#  ' 740000',
#  ' 495000',
#  ' 370000',
#  ' 340000',
#  ' 450000',
#  ' 375000',
#  ' 460000',
#  ' 320000',
#  ' 315000',
#  ' 445000',
#  ' 825000',
#  ' 1145000',
#  ' 445000',
#  ' 440000',
#  ' 139000',
#  ' 175000',
#  ' 1099000',
#  ' 415000',
#  ' 2250000',
#  ' 1400000',
#  ' 195000',
#  ' 290000',
#  ' 535000',
#  ' 280000',
#  ' 310000',
#  ' 560000',
#  ' 750000',
#  ' 680000',
#  ' 225000',
#  ' 380000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_6)):
    Price_6[i] = int(Price_6[i])

# %%
#Printing after conversion

Price_6
# Out:
# [6800000,
#  710000,
#  775000,
#  275000,
#  350000,
#  295000,
#  410000,
#  249000,
#  210000,
#  420000,
#  465000,
#  220000,
#  645000,
#  390000,
#  465000,
#  690000,
#  600000,
#  265000,
#  174000,
#  170000,
#  950000,
#  700000,
#  4400000,
#  263000,
#  155000,
#  355000,
#  225000,
#  1450000,
#  615000,
#  535000,
#  415000,
#  425000,
#  435000,
#  795000,
#  525000,
#  485000,
#  325000,
#  390000,
#  490000,
#  230000,
#  740000,
#  495000,
#  370000,
#  340000,
#  450000,
#  375000,
#  460000,
#  320000,
#  315000,
#  445000,
#  825000,
#  1145000,
#  445000,
#  440000,
#  139000,
#  175000,
#  1099000,
#  415000,
#  2250000,
#  1400000,
#  195000,
#  290000,
#  535000,
#  280000,
#  310000,
#  560000,
#  750000,
#  680000,
#  225000,
#  380000,
#  365000,
#  555000,
#  650000,
#  248000,
#  510000,
#  4000000,
#  730000,
#  950000,
#  395000,
#  950000,
#  395000,
#  265000,
#  340000,
#  345000,
#  650000,
#  360000,
#  1899000,
#  550000,
#  325000,
#  550000,
# ...

# %%
#Fetching data from olx for Year

for y6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_6.append(y6.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_6)):
    Year_6[i] = int(Year_6[i])

# %%
#Printing after conversion

Year_6
# Out:
# [2020,
#  2018,
#  2014,
#  2012,
#  2009,
#  2014,
#  2013,
#  2010,
#  2009,
#  2011,
#  2014,
#  2003,
#  2015,
#  2011,
#  2011,
#  2015,
#  2018,
#  2011,
#  2013,
#  2007,
#  2012,
#  2018,
#  2017,
#  2014,
#  2012,
#  2012,
#  2010,
#  2013,
#  2016,
#  2012,
#  2014,
#  2011,
#  2015,
#  2016,
#  2016,
#  2014,
#  2017,
#  2014,
#  2010,
#  2011,
#  2014,
#  2016,
#  2009,
#  2012,
#  2013,
#  2014,
#  2013,
#  2017,
#  2009,
#  2014,
#  2017,
#  2016,
#  2017,
#  2011,
#  2008,
#  2008,
#  2018,
#  2018,
#  2014,
#  2017,
#  2007,
#  2007,
#  2015,
#  2012,
#  2011,
#  2018,
#  2017,
#  2017,
#  2010,
#  2018,
#  2011,
#  2015,
#  2008,
#  2012,
#  2013,
#  2017,
#  2012,
#  2016,
#  2013,
#  2019,
#  2017,
#  2009,
#  2010,
#  2011,
#  2014,
#  2009,
#  2013,
#  2019,
#  2011,
#  2013,
#  2016,
#  2016,
#  2010,
#  2012,
#  2018,
#  2015,
#  2002,
#  2012,
#  2007,
#  2014,
#  2014,
#  2014,
#  2015,
#  2016,
#  2017,
#  2016,
#  2005,
#  2009,
#  2017,
#  2016,
#  2017,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_6.append(k6.text.split('-')[1])
for c6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_6.append(c6.text)
for l6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_6.append(l6.text)
for d6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_6.append(d6.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS6=pd.DataFrame({})
CARS6['PRICE']=Price_6[0:500]
CARS6['YEAR']=Year_6[0:500]
CARS6['KM']=Km_6[0:500]
CARS6['COMPANY']=Company_6[0:500]
CARS6['LOCATION']=Location_6[0:500]
CARS6['POSTED-DATE']=Date_6[0:500]

# %%
#Printing the dataframe

CARS6
# Out:
#        PRICE  YEAR           KM                 COMPANY  \
# 0    6800000  2020    20,000 km                  BMW X4
# 1     710000  2018    76,000 km           Mahindra Xylo
# 2     775000  2014   174,000 km         Mahindra XUV500
# 3     275000  2012    30,000 km  Chevrolet Optra Magnum
# 4     350000  2009    71,600 km    Toyota Corolla Altis
# ..       ...   ...          ...                     ...
# 495   140000  2017   119,000 km         Tata Indica Ev2
# 496   415000  2013    68,000 km              Honda City
# 497   560000  2015   480,003 km     Maruti Suzuki Swift
# 498   425000  2016    65,000 km   Maruti Suzuki Celerio
# 499  1380000  2014    90,000 km            Skoda Superb
#
#                                        LOCATION POSTED-DATE
# 0                            Mount Road\nJan 09      Jan 09
# 1                          Nungambakkam\nNov 30      Nov 30
# 2                          Perambur\n3 days ago  3 days ago
# ...

# %%
#Getting the information about the dataset

CARS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
driver6.close()

# %% [markdown]
# # 2998 IN TOTAL NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver6 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver6.get('https://www.olx.in/en-in/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_6=[]
Year_6=[]
Km_6=[]
Company_6=[]
Location_6=[]
Date_6=[]

# %%
#Fetching the data from olx for Price

for p6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_6.append(p6.text.replace("₹","").replace(",",""))

# %%
Price_6
# Out:
# [' 1950000',
#  ' 275000',
#  ' 1350000',
#  ' 545000',
#  ' 475000',
#  ' 475000',
#  ' 475000',
#  ' 4900000',
#  ' 511000',
#  ' 399999',
#  ' 275000',
#  ' 159013',
#  ' 399000',
#  ' 475000',
#  ' 325000',
#  ' 475000',
#  ' 270000',
#  ' 325000',
#  ' 1950000',
#  ' 970000',
#  ' 1490000',
#  ' 525000',
#  ' 165000',
#  ' 1935000',
#  ' 555000',
#  ' 311000',
#  ' 835000',
#  ' 1090000',
#  ' 865000',
#  ' 635000',
#  ' 1600000',
#  ' 625000',
#  ' 970000',
#  ' 260000',
#  ' 710000',
#  ' 499999',
#  ' 969000',
#  ' 395000',
#  ' 374000',
#  ' 199000',
#  ' 925000',
#  ' 1390000',
#  ' 215000',
#  ' 185000',
#  ' 250000',
#  ' 270000',
#  ' 299000',
#  ' 165000',
#  ' 699000',
#  ' 510000',
#  ' 1749000',
#  ' 425000',
#  ' 435000',
#  ' 575000',
#  ' 1365000',
#  ' 245000',
#  ' 499000',
#  ' 525000',
#  ' 470000',
#  ' 400000',
#  ' 700000',
#  ' 5500000',
#  ' 135000',
#  ' 200000',
#  ' 300000',
#  ' 360000',
#  ' 230000',
#  ' 750000',
#  ' 190000',
#  ' 580000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_6)):
    Price_6[i] = int(Price_6[i])

# %%
#Printing after conversion

Price_6
# Out:
# [1950000,
#  275000,
#  1350000,
#  545000,
#  475000,
#  475000,
#  475000,
#  4900000,
#  511000,
#  399999,
#  275000,
#  159013,
#  399000,
#  475000,
#  325000,
#  475000,
#  270000,
#  325000,
#  1950000,
#  970000,
#  1490000,
#  525000,
#  165000,
#  1935000,
#  555000,
#  311000,
#  835000,
#  1090000,
#  865000,
#  635000,
#  1600000,
#  625000,
#  970000,
#  260000,
#  710000,
#  499999,
#  969000,
#  395000,
#  374000,
#  199000,
#  925000,
#  1390000,
#  215000,
#  185000,
#  250000,
#  270000,
#  299000,
#  165000,
#  699000,
#  510000,
#  1749000,
#  425000,
#  435000,
#  575000,
#  1365000,
#  245000,
#  499000,
#  525000,
#  470000,
#  400000,
#  700000,
#  5500000,
#  135000,
#  200000,
#  300000,
#  360000,
#  230000,
#  750000,
#  190000,
#  580000,
#  445000,
#  395000,
#  260000,
#  555000,
#  500000,
#  53453,
#  390000,
#  525000,
#  225000,
#  815000,
#  500000,
#  935000,
#  159999,
#  575000,
#  1375000,
#  678000,
#  379999,
#  240000,
#  100000,
# ...

# %%
#Fetching data from olx for Year

for y6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_6.append(y6.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_6)):
    Year_6[i] = int(Year_6[i])

# %%
#Printing after conversion

Year_6
# Out:
# [2011,
#  2013,
#  2009,
#  2016,
#  2013,
#  2013,
#  2017,
#  2017,
#  2013,
#  2011,
#  2013,
#  2006,
#  2012,
#  2017,
#  2011,
#  2015,
#  2010,
#  2010,
#  2021,
#  2016,
#  2017,
#  2015,
#  2009,
#  2020,
#  2019,
#  2016,
#  2017,
#  2015,
#  2019,
#  2014,
#  2015,
#  2017,
#  2019,
#  2012,
#  2019,
#  2013,
#  2016,
#  2013,
#  2016,
#  2008,
#  2019,
#  2014,
#  2009,
#  2018,
#  2007,
#  2007,
#  2015,
#  2010,
#  2012,
#  2014,
#  2018,
#  2017,
#  2014,
#  2012,
#  2017,
#  2010,
#  2012,
#  2014,
#  2014,
#  2013,
#  1996,
#  2019,
#  2008,
#  2009,
#  2008,
#  2017,
#  2012,
#  2021,
#  2011,
#  2016,
#  2011,
#  2011,
#  2010,
#  2011,
#  2020,
#  2009,
#  2016,
#  2009,
#  2014,
#  2013,
#  2014,
#  2016,
#  2014,
#  2016,
#  2021,
#  2014,
#  2016,
#  2012,
#  2006,
#  2015,
#  2020,
#  2008,
#  2018,
#  2019,
#  2011,
#  2007,
#  2011,
#  2007,
#  2014,
#  2012,
#  2016,
#  2019,
#  2007,
#  2016,
#  2021,
#  2018,
#  2011,
#  2019,
#  2010,
#  2020,
#  2019,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_6.append(k6.text.split('-')[1])
for c6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_6.append(c6.text)
for l6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_6.append(l6.text)
for d6 in driver6.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_6.append(d6.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS6=pd.DataFrame({})
CARS6['PRICE']=Price_6[0:500]
CARS6['YEAR']=Year_6[0:500]
CARS6['KM']=Km_6[0:500]
CARS6['COMPANY']=Company_6[0:500]
CARS6['LOCATION']=Location_6[0:500]
CARS6['POSTED-DATE']=Date_6[0:500]

# %%
#Printing the dataframe

CARS6
# Out:
#        PRICE  YEAR           KM                  COMPANY  \
# 0    1950000  2011    58,000 km  Mercedes-Benz CLS-Class
# 1     275000  2013    60,000 km    Maruti Suzuki Wagon R
# 2    1350000  2009   113,000 km                   BMW X5
# 3     545000  2016    23,000 km     Maruti Suzuki Baleno
# 4     475000  2013    75,000 km             Skoda Superb
# ..       ...   ...          ...                      ...
# 495   300000  2019    10,470 km   Maruti Suzuki Alto 800
# 496   135000  2008   119,000 km       Maruti Suzuki Alto
# 497   140000  2008   106,706 km       Maruti Suzuki Omni
# 498   125000  2010   100,000 km       Maruti Suzuki Alto
# 499    99000  2012    82,000 km          Tata Indigo Ecs
#
#                       LOCATION POSTED-DATE
# 0    North Kalamassery\nDec 06      Dec 06
# 1          Brijlalpura\nJan 05      Jan 05
# 2             RS Puram\nDec 29      Dec 29
# 3                Kalyan\nToday       Today
# 4                Kalyan\nToday       Today
# ...

# %%
#Getting the information abput the dataset

CARS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
driver6.close()

# %% [markdown]
# # 3498 IN TOTAL NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver7 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver7.get('https://www.olx.in/en-in/lucknow_g4059306/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_7=[]
Year_7=[]
Km_7=[]
Company_7=[]
Location_7=[]
Date_7=[]

# %%
#Fetching the data from olx for Price

for p7 in driver7.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_7.append(p7.text.replace("₹","").replace(",",""))

# %%
#Printing price

Price_7
# Out:
# [' 750000',
#  ' 1700000',
#  ' 4675000',
#  ' 200000',
#  ' 1800000',
#  ' 190000',
#  ' 1025000',
#  ' 550000',
#  ' 460000',
#  ' 1050000',
#  ' 1950000',
#  ' 900000',
#  ' 690000',
#  ' 325000',
#  ' 490000',
#  ' 1350000',
#  ' 750000',
#  ' 375000',
#  ' 775000',
#  ' 1790000',
#  ' 465000',
#  ' 5500000',
#  ' 6200000',
#  ' 249000',
#  ' 160000',
#  ' 499000',
#  ' 1075000',
#  ' 585000',
#  ' 625000',
#  ' 290000',
#  ' 220000',
#  ' 315000',
#  ' 2350000',
#  ' 375000',
#  ' 265000',
#  ' 350000',
#  ' 170000',
#  ' 340000',
#  ' 385000',
#  ' 2750000',
#  ' 530000',
#  ' 225000',
#  ' 4250000',
#  ' 445000',
#  ' 64000',
#  ' 250000',
#  ' 1270000',
#  ' 120000',
#  ' 745000',
#  ' 290000',
#  ' 775000',
#  ' 950000',
#  ' 3450000',
#  ' 165000',
#  ' 4950000',
#  ' 62500',
#  ' 295000',
#  ' 285000',
#  ' 3650000',
#  ' 190000',
#  ' 1550000',
#  ' 1450000',
#  ' 440000',
#  ' 1950000',
#  ' 590000',
#  ' 315000',
#  ' 625000',
#  ' 700000',
#  ' 235000',
#  ' 375000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_7)):
    Price_7[i] = int(Price_7[i])

# %%
#Printing after conversion

Price_7
# Out:
# [750000,
#  1700000,
#  4675000,
#  200000,
#  1800000,
#  190000,
#  1025000,
#  550000,
#  460000,
#  1050000,
#  1950000,
#  900000,
#  690000,
#  325000,
#  490000,
#  1350000,
#  750000,
#  375000,
#  775000,
#  1790000,
#  465000,
#  5500000,
#  6200000,
#  249000,
#  160000,
#  499000,
#  1075000,
#  585000,
#  625000,
#  290000,
#  220000,
#  315000,
#  2350000,
#  375000,
#  265000,
#  350000,
#  170000,
#  340000,
#  385000,
#  2750000,
#  530000,
#  225000,
#  4250000,
#  445000,
#  64000,
#  250000,
#  1270000,
#  120000,
#  745000,
#  290000,
#  775000,
#  950000,
#  3450000,
#  165000,
#  4950000,
#  62500,
#  295000,
#  285000,
#  3650000,
#  190000,
#  1550000,
#  1450000,
#  440000,
#  1950000,
#  590000,
#  315000,
#  625000,
#  700000,
#  235000,
#  375000,
#  380000,
#  265000,
#  1130000,
#  219000,
#  695000,
#  685000,
#  400000,
#  389000,
#  1790000,
#  1490000,
#  625000,
#  1375000,
#  585000,
#  1375000,
#  185000,
#  550000,
#  925000,
#  540000,
# ...

# %%
#Fetching data from olx for Year

for y7 in driver7.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_7.append(y7.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_7)):
    Year_7[i] = float(Year_7[i])

# %%
#Printing the Year

Year_7
# Out:
# [1996.0,
#  2016.0,
#  2018.0,
#  2016.0,
#  2014.0,
#  2011.0,
#  2018.0,
#  2014.0,
#  2018.0,
#  2020.0,
#  2021.0,
#  2015.0,
#  2016.0,
#  2017.0,
#  2015.0,
#  2013.0,
#  2016.0,
#  2018.0,
#  2017.0,
#  2012.0,
#  2012.0,
#  2019.0,
#  2019.0,
#  2011.0,
#  2011.0,
#  2015.0,
#  2017.0,
#  2018.0,
#  2015.0,
#  2016.0,
#  2009.0,
#  2013.0,
#  2020.0,
#  2016.0,
#  2011.0,
#  2015.0,
#  2011.0,
#  2012.0,
#  2014.0,
#  2017.0,
#  2015.0,
#  2015.0,
#  2012.0,
#  2016.0,
#  2007.0,
#  2017.0,
#  2014.0,
#  2015.0,
#  2018.0,
#  2011.0,
#  2015.0,
#  2011.0,
#  2019.0,
#  2011.0,
#  2020.0,
#  2007.0,
#  2013.0,
#  2017.0,
#  2018.0,
#  2010.0,
#  2019.0,
#  2020.0,
#  2014.0,
#  2018.0,
#  2020.0,
#  2008.0,
#  2014.0,
#  2016.0,
#  2009.0,
#  2014.0,
#  2017.0,
#  2017.0,
#  2016.0,
#  2010.0,
#  2015.0,
#  2017.0,
#  2016.0,
#  2014.0,
#  2013.0,
#  2013.0,
#  2016.0,
#  2012.0,
#  2016.0,
#  2012.0,
#  2010.0,
#  2014.0,
#  2020.0,
#  2015.0,
#  2017.0,
#  2015.0,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k7 in driver7.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_7.append(k7.text.split('-')[1])
for c7 in driver7.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_7.append(c7.text)
for l7 in driver7.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_7.append(l7.text)
for d7 in driver7.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_7.append(d7.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS7=pd.DataFrame({})
CARS7['PRICE']=Price_7[0:500]
CARS7['YEAR']=Year_7[0:500]
CARS7['KM']=Km_7[0:500]
CARS7['COMPANY']=Company_7[0:500]
CARS7['LOCATION']=Location_7[0:500]
CARS7['POSTED-DATE']=Date_7[0:500]

# %%
#Printing the dataframe

CARS7
# Out:
#        PRICE    YEAR           KM                     COMPANY  \
# 0     750000  1996.0    56,000 km   Hindustan Motors Contessa
# 1    1700000  2016.0   115,000 km              Ford Endeavour
# 2    4675000  2018.0    58,000 km  Land Rover Discovery Sport
# 3     200000  2016.0    30,000 km          Maruti Suzuki Omni
# 4    1800000  2014.0    70,000 km                      BMW X3
# ..       ...     ...          ...                         ...
# 495   290000  2011.0   120,000 km                 Tata Safari
# 496   148000  2011.0    70,000 km           Fiat Grande Punto
# 497   230000  2011.0    70,000 km                 Hyundai i20
# 498  1890000  2019.0    25,000 km        Toyota Innova Crysta
# 499  4600000  2020.0    10,000 km             BMW 3 Series GT
#
#                                   LOCATION POSTED-DATE
# 0                       Hazratganj\nDec 25      Dec 25
# 1                       Hazratganj\nDec 20      Dec 20
# ...

# %%
#Getting the information of the dataset

CARS7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    float64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 23.6+ KB

# %%
driver7.close()

# %% [markdown]
# # 3998 IN TOTAL NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver8 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver8.get('https://www.olx.in/en-in/punjab_g2001170/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_8=[]
Year_8=[]
Km_8=[]
Company_8=[]
Location_8=[]
Date_8=[]

# %%
#Fetching the data from olx for Price

for p8 in driver8.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_8.append(p8.text.replace("₹","").replace(",",""))

# %%
Price_8
# Out:
# [' 600000',
#  ' 2350000',
#  ' 2800000',
#  ' 198000',
#  ' 275000',
#  ' 1850000',
#  ' 850000',
#  ' 850000',
#  ' 270000',
#  ' 145000',
#  ' 1325000',
#  ' 175000',
#  ' 190000',
#  ' 190000',
#  ' 80000',
#  ' 390000',
#  ' 160000',
#  ' 75000',
#  ' 178000',
#  ' 140000',
#  ' 495000',
#  ' 4950000',
#  ' 1150000',
#  ' 220000',
#  ' 470000',
#  ' 180000',
#  ' 1475000',
#  ' 600000',
#  ' 435000',
#  ' 1099999',
#  ' 1725000',
#  ' 48000',
#  ' 850000',
#  ' 375000',
#  ' 80000',
#  ' 390000',
#  ' 525000',
#  ' 815000',
#  ' 625000',
#  ' 550000',
#  ' 385000',
#  ' 345000',
#  ' 925000',
#  ' 460000',
#  ' 230000',
#  ' 460000',
#  ' 220000',
#  ' 95000',
#  ' 270000',
#  ' 180000',
#  ' 140000',
#  ' 775000',
#  ' 785000',
#  ' 300000',
#  ' 790000',
#  ' 725000',
#  ' 1315000',
#  ' 95000',
#  ' 115000',
#  ' 189999',
#  ' 220000',
#  ' 630000',
#  ' 265000',
#  ' 405000',
#  ' 390000',
#  ' 720000',
#  ' 500000',
#  ' 85000',
#  ' 480000',
#  ' 630000',
#  ' 600000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_8)):
    Price_8[i] = int(Price_8[i])

# %%
#Printing after conversion

Price_8
# Out:
# [600000,
#  2350000,
#  2800000,
#  198000,
#  275000,
#  1850000,
#  850000,
#  850000,
#  270000,
#  145000,
#  1325000,
#  175000,
#  190000,
#  190000,
#  80000,
#  390000,
#  160000,
#  75000,
#  178000,
#  140000,
#  495000,
#  4950000,
#  1150000,
#  220000,
#  470000,
#  180000,
#  1475000,
#  600000,
#  435000,
#  1099999,
#  1725000,
#  48000,
#  850000,
#  375000,
#  80000,
#  390000,
#  525000,
#  815000,
#  625000,
#  550000,
#  385000,
#  345000,
#  925000,
#  460000,
#  230000,
#  460000,
#  220000,
#  95000,
#  270000,
#  180000,
#  140000,
#  775000,
#  785000,
#  300000,
#  790000,
#  725000,
#  1315000,
#  95000,
#  115000,
#  189999,
#  220000,
#  630000,
#  265000,
#  405000,
#  390000,
#  720000,
#  500000,
#  85000,
#  480000,
#  630000,
#  600000,
#  160000,
#  330000,
#  75000,
#  85000,
#  180000,
#  470000,
#  15000,
#  115000,
#  180000,
#  1075000,
#  1150000,
#  390000,
#  429000,
#  128000,
#  550000,
#  195000,
#  141000,
#  265000,
#  32000,
# ...

# %%
#Fetching data from olx for Year

for y8 in driver8.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_8.append(y8.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_8)):
    Year_8[i] = int(Year_8[i])

# %%
#Printing after conversion

Year_8
# Out:
# [2016,
#  2013,
#  2011,
#  2012,
#  2013,
#  2015,
#  2007,
#  2008,
#  2011,
#  2007,
#  2019,
#  2012,
#  2009,
#  2012,
#  2006,
#  2011,
#  2009,
#  2009,
#  2013,
#  2007,
#  2012,
#  2015,
#  2017,
#  2010,
#  2011,
#  2007,
#  2021,
#  2017,
#  2016,
#  2018,
#  2018,
#  1998,
#  2017,
#  2014,
#  2000,
#  2016,
#  2009,
#  2013,
#  2013,
#  2016,
#  2013,
#  2013,
#  2010,
#  2011,
#  2005,
#  2014,
#  2010,
#  2004,
#  2010,
#  2009,
#  2010,
#  2015,
#  2012,
#  2019,
#  2018,
#  2020,
#  2018,
#  2004,
#  2007,
#  2012,
#  2007,
#  2019,
#  2012,
#  2013,
#  2013,
#  2021,
#  2016,
#  2003,
#  2018,
#  2017,
#  2021,
#  2011,
#  2017,
#  2006,
#  2002,
#  2010,
#  2013,
#  2021,
#  2007,
#  2008,
#  2019,
#  2013,
#  2012,
#  2013,
#  2007,
#  2012,
#  2008,
#  2011,
#  2015,
#  2001,
#  2012,
#  2018,
#  2013,
#  2013,
#  2019,
#  2004,
#  2011,
#  2016,
#  2019,
#  2010,
#  2008,
#  2015,
#  2019,
#  2012,
#  2014,
#  2020,
#  2013,
#  2008,
#  2012,
#  2014,
#  2020,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k8 in driver8.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_8.append(k8.text.split('-')[1])
for c8 in driver8.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_8.append(c8.text)
for l8 in driver8.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_8.append(l8.text)
for d8 in driver8.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_8.append(d8.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS8=pd.DataFrame({})
CARS8['PRICE']=Price_8[0:500]
CARS8['YEAR']=Year_8[0:500]
CARS8['KM']=Km_8[0:500]
CARS8['COMPANY']=Company_8[0:500]
CARS8['LOCATION']=Location_8[0:500]
CARS8['POSTED-DATE']=Date_8[0:500]

# %%
#Printing the dataframe

CARS8
# Out:
#        PRICE  YEAR           KM                         COMPANY  \
# 0     600000  2016    68,000 km              Maruti Suzuki Ciaz
# 1    2350000  2013    91,000 km   Land Rover Range Rover Evoque
# 2    2800000  2011    31,000 km                    BMW 6 Series
# 3     198000  2012   120,000 km              Maruti Suzuki Ritz
# 4     275000  2013   120,000 km  Maruti Suzuki Swift Dzire Tour
# ..       ...   ...          ...                             ...
# 494   220000  2018     7,500 km                     Tata Others
# 495   350000  2012    65,000 km                    Nissan Sunny
# 496   150000  2014   112,452 km                 Tata Indigo Ecs
# 497   350000  2011    68,000 km                     Hyundai i20
# 498    64000  2001    67,000 km               Maruti Suzuki Zen
#
#                            LOCATION POSTED-DATE
# 0                Model Gram\nDec 12      Dec 12
# 1                 Sector 82\nJan 14      Jan 14
# 2                 Sector 82\nSep 23      Sep 23
# ...

# %%
#Getting the information about the dataset

CARS8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        499 non-null    int64
#  1   YEAR         499 non-null    int64
#  2   KM           499 non-null    object
#  3   COMPANY      499 non-null    object
#  4   LOCATION     499 non-null    object
#  5   POSTED-DATE  499 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.5+ KB

# %%
driver8.close()

# %% [markdown]
# # 4497 IN TOTAL NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver9 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver9.get('https://www.olx.in/en-in/haryana_g2001155/cars_c84?isSearchCall=false')

# %%
#Creating empty lists so that we can fetch the data

Price_9=[]
Year_9=[]
Km_9=[]
Company_9=[]
Location_9=[]
Date_9=[]

# %%
#Fetching the data from olx for Price

for p9 in driver9.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_9.append(p9.text.replace("₹","").replace(",",""))

# %%
#Printing the price

Price_9
# Out:
# [' 1380000',
#  ' 915000',
#  ' 1050000',
#  ' 400000',
#  ' 160000',
#  ' 175000',
#  ' 1300000',
#  ' 110000',
#  ' 550000',
#  ' 80000',
#  ' 95000',
#  ' 480000',
#  ' 435000',
#  ' 340000',
#  ' 5700000',
#  ' 150000',
#  ' 725000',
#  ' 160000',
#  ' 365000',
#  ' 310000',
#  ' 713400',
#  ' 300000',
#  ' 3350000',
#  ' 350000',
#  ' 295000',
#  ' 150000',
#  ' 426000',
#  ' 165000',
#  ' 340000',
#  ' 650000',
#  ' 115000',
#  ' 990000',
#  ' 560000',
#  ' 950000',
#  ' 1680000',
#  ' 405000',
#  ' 370000',
#  ' 280000',
#  ' 185000',
#  ' 640000',
#  ' 590000',
#  ' 886000',
#  ' 713400',
#  ' 650000',
#  ' 750000',
#  ' 550000',
#  ' 2125000',
#  ' 225000',
#  ' 425000',
#  ' 599999',
#  ' 300000',
#  ' 85000',
#  ' 250000',
#  ' 125000',
#  ' 300000',
#  ' 135000',
#  ' 490000',
#  ' 240000',
#  ' 370000',
#  ' 225000',
#  ' 270000',
#  ' 135000',
#  ' 1099000',
#  ' 145000',
#  ' 430000',
#  ' 5700000',
#  ' 230000',
#  ' 260000',
#  ' 52000',
#  ' 410000',
#  ' 350000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_9)):
    Price_9[i] = int(Price_9[i])

# %%
#Printing after conversion

Price_9
# Out:
# [1380000,
#  915000,
#  1050000,
#  400000,
#  160000,
#  175000,
#  1300000,
#  110000,
#  550000,
#  80000,
#  95000,
#  480000,
#  435000,
#  340000,
#  5700000,
#  150000,
#  725000,
#  160000,
#  365000,
#  310000,
#  713400,
#  300000,
#  3350000,
#  350000,
#  295000,
#  150000,
#  426000,
#  165000,
#  340000,
#  650000,
#  115000,
#  990000,
#  560000,
#  950000,
#  1680000,
#  405000,
#  370000,
#  280000,
#  185000,
#  640000,
#  590000,
#  886000,
#  713400,
#  650000,
#  750000,
#  550000,
#  2125000,
#  225000,
#  425000,
#  599999,
#  300000,
#  85000,
#  250000,
#  125000,
#  300000,
#  135000,
#  490000,
#  240000,
#  370000,
#  225000,
#  270000,
#  135000,
#  1099000,
#  145000,
#  430000,
#  5700000,
#  230000,
#  260000,
#  52000,
#  410000,
#  350000,
#  80000,
#  300000,
#  235000,
#  70000,
#  4490000,
#  2250000,
#  250000,
#  270000,
#  850000,
#  13900000,
#  580000,
#  950000,
#  140000,
#  400000,
#  140000,
#  250000,
#  550000,
#  1370000,
#  380000,
# ...

# %%
#Fetching data from olx for Year

for y9 in driver9.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_9.append(y9.text.split('-')[0])

# %%
#Converting the column into integer type

for i in range(0, len(Year_9)):
    Year_9[i] = int(Year_9[i])

# %%
#Printing after conversion

Year_9
# Out:
# [2018,
#  2019,
#  2016,
#  2012,
#  2010,
#  2012,
#  2012,
#  2010,
#  2016,
#  2007,
#  2007,
#  2017,
#  2015,
#  2017,
#  2016,
#  2014,
#  2018,
#  2011,
#  2016,
#  2011,
#  2019,
#  2013,
#  2019,
#  2014,
#  2013,
#  2008,
#  2013,
#  2011,
#  2015,
#  2017,
#  2004,
#  2012,
#  2020,
#  2019,
#  2014,
#  2018,
#  2015,
#  2012,
#  2010,
#  2015,
#  2017,
#  2019,
#  2019,
#  2021,
#  2016,
#  2014,
#  2015,
#  2011,
#  2018,
#  2015,
#  2014,
#  2008,
#  2012,
#  2009,
#  2012,
#  2007,
#  2018,
#  2011,
#  2012,
#  2009,
#  2015,
#  2007,
#  2011,
#  2012,
#  2021,
#  2021,
#  2016,
#  2017,
#  1997,
#  2018,
#  2020,
#  2007,
#  2017,
#  2011,
#  2004,
#  2017,
#  2021,
#  2010,
#  2011,
#  2019,
#  2018,
#  2018,
#  2020,
#  2010,
#  2014,
#  2010,
#  2012,
#  2021,
#  2021,
#  2014,
#  2014,
#  2015,
#  2016,
#  2020,
#  2015,
#  2016,
#  2021,
#  2008,
#  2010,
#  2013,
#  2016,
#  2010,
#  2016,
#  2013,
#  2014,
#  2015,
#  2013,
#  2021,
#  2016,
#  2014,
#  2015,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k9 in driver9.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_9.append(k9.text.split('-')[1])
for c9 in driver9.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_9.append(c9.text)
for l9 in driver9.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_9.append(l9.text)
for d9 in driver9.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_9.append(d9.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS9=pd.DataFrame({})
CARS9['PRICE']=Price_9[0:500]
CARS9['YEAR']=Year_9[0:500]
CARS9['KM']=Km_9[0:500]
CARS9['COMPANY']=Company_9[0:500]
CARS9['LOCATION']=Location_9[0:500]
CARS9['POSTED-DATE']=Date_9[0:500]

# %%
#Printing the dataframe

CARS9
# Out:
#        PRICE  YEAR           KM                 COMPANY  \
# 0    1380000  2018   53134.0 km            Jeep Compass
# 1     915000  2019    46,000 km              Honda City
# 2    1050000  2016    78,000 km        Mahindra Scorpio
# 3     400000  2012    95,000 km        Volkswagen Jetta
# 4     160000  2010   120,000 km      Maruti Suzuki Ritz
# ..       ...   ...          ...                     ...
# 495  1390000  2014    58,000 km                 Audi Q3
# 496   280000  2012    80,000 km    Maruti Suzuki Ertiga
# 497    45000  2006   118,000 km  Maruti Suzuki Alto 800
# 498   325000  2017    88,000 km           Hyundai Xcent
# 499   700000  2018    73,000 km      Hyundai i20 Active
#
#                     LOCATION POSTED-DATE
# 0            MG Road\nDec 13      Dec 13
# 1          Sector 13\nJan 06      Jan 06
# 2    Vikas Nagar\n2 days ago  2 days ago
# 3           Dc Colony\nToday       Today
# 4               Sohna\nToday       Today
# ...

# %%
#Printing the ibnformation of the dataset

CARS9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
driver9.close()

# %% [markdown]
# # 4997 IN TOTAL NOW

# %%
#Creating an instance of the chrome driver to get to the url

driver10 = webdriver.Chrome(r'E:/CHROME-DRIVER/chromedriver_win32/chromedriver.exe')

# %%
#Getting into the website

driver10.get('https://www.olx.in/en-in/kerala_g2001160/cars_c84')

# %%
#Creating empty lists so that we can fetch the data

Price_10=[]
Year_10=[]
Km_10=[]
Company_10=[]
Location_10=[]
Date_10=[]

# %%
#Fetching the data from olx for Price

for p10 in driver10.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/span"):
    Price_10.append(p10.text.replace("₹","").replace(",",""))

# %%
#Printing the price

Price_10
# Out:
# [' 645000',
#  ' 725000',
#  ' 13500000',
#  ' 35000',
#  ' 185000',
#  ' 125000',
#  ' 145000',
#  ' 265000',
#  ' 80000',
#  ' 585000',
#  ' 260000',
#  ' 80000',
#  ' 1140000',
#  ' 245000',
#  ' 435000',
#  ' 485000',
#  ' 1000000',
#  ' 3500000',
#  ' 400000',
#  ' 1950000',
#  ' 590000',
#  ' 235000',
#  ' 1450000',
#  ' 210000',
#  ' 420000',
#  ' 190000',
#  ' 485000',
#  ' 720000',
#  ' 27000',
#  ' 250000',
#  ' 200000',
#  ' 475000',
#  ' 465000',
#  ' 775000',
#  ' 150000',
#  ' 450000',
#  ' 150000',
#  ' 1590000',
#  ' 305000',
#  ' 230000',
#  ' 199999',
#  ' 1444444',
#  ' 5000000',
#  ' 73000',
#  ' 1970000',
#  ' 350000',
#  ' 615000',
#  ' 615000',
#  ' 750000',
#  ' 195000',
#  ' 1250000',
#  ' 1990000',
#  ' 695000',
#  ' 310000',
#  ' 3400000',
#  ' 90000',
#  ' 470000',
#  ' 150000',
#  ' 155000',
#  ' 205000',
#  ' 125000',
#  ' 125000',
#  ' 275000',
#  ' 650000',
#  ' 700000',
#  ' 110000',
#  ' 230000',
#  ' 160000',
#  ' 385000',
#  ' 290000',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Price_10)):
    Price_10[i] = int(Price_10[i])

# %%
#Printing after conversion

Price_10
# Out:
# [645000,
#  725000,
#  13500000,
#  35000,
#  185000,
#  125000,
#  145000,
#  265000,
#  80000,
#  585000,
#  260000,
#  80000,
#  1140000,
#  245000,
#  435000,
#  485000,
#  1000000,
#  3500000,
#  400000,
#  1950000,
#  590000,
#  235000,
#  1450000,
#  210000,
#  420000,
#  190000,
#  485000,
#  720000,
#  27000,
#  250000,
#  200000,
#  475000,
#  465000,
#  775000,
#  150000,
#  450000,
#  150000,
#  1590000,
#  305000,
#  230000,
#  199999,
#  1444444,
#  5000000,
#  73000,
#  1970000,
#  350000,
#  615000,
#  615000,
#  750000,
#  195000,
#  1250000,
#  1990000,
#  695000,
#  310000,
#  3400000,
#  90000,
#  470000,
#  150000,
#  155000,
#  205000,
#  125000,
#  125000,
#  275000,
#  650000,
#  700000,
#  110000,
#  230000,
#  160000,
#  385000,
#  290000,
#  450000,
#  155000,
#  390000,
#  43000,
#  45000,
#  161000,
#  237000,
#  198000,
#  303000,
#  699000,
#  1750000,
#  69000,
#  745000,
#  1085000,
#  2580000,
#  380000,
#  529000,
#  320000,
#  929000,
#  98000,
# ...

# %%
#Fetching data from olx for Year

for y10 in driver10.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Year_10.append(y10.text.split('-')[0])

# %%
#Printing the year

Year_10
# Out:
# ['2018 ',
#  '2017 ',
#  '2020 ',
#  '1998 ',
#  '2008 ',
#  '2006 ',
#  '2015 ',
#  '2013 ',
#  '2006 ',
#  '2015 ',
#  '2016 ',
#  '2010 ',
#  '2021 ',
#  '2015 ',
#  '2014 ',
#  '2017 ',
#  '2016 ',
#  '2016 ',
#  '2013 ',
#  '2014 ',
#  '2015 ',
#  '2009 ',
#  '2017 ',
#  '2013 ',
#  '2019 ',
#  '2009 ',
#  '2015 ',
#  '2017 ',
#  '2003 ',
#  '2011 ',
#  '2004 ',
#  '2015 ',
#  '2018 ',
#  '2018 ',
#  '2011 ',
#  '2014 ',
#  '2012 ',
#  '2014 ',
#  '2017 ',
#  '2010 ',
#  '2011 ',
#  '2018 ',
#  '2019 ',
#  '2007 ',
#  '2021 ',
#  '2017 ',
#  '2020 ',
#  '2020 ',
#  '2018 ',
#  '2010 ',
#  '2019 ',
#  '2015 ',
#  '2019 ',
#  '2001 ',
#  '2013 ',
#  '2009 ',
#  '2020 ',
#  '2008 ',
#  '2009 ',
#  '2010 ',
#  '2008 ',
#  '2009 ',
#  '2012 ',
#  '2012 ',
#  '2011 ',
#  '2009 ',
#  '2016 ',
#  '2004 ',
#  '2016 ',
#  '2018 ',
#  '2018 ',
#  '2008 ',
#  '2012 ',
#  '2003 ',
#  '2003 ',
#  '2011 ',
#  '2005 ',
#  '2015 ',
#  '2012 ',
#  '2016 ',
#  '2013 ',
#  '2001 ',
#  '2019 ',
# ...

# %%
#Converting the column into integer type

for i in range(0, len(Year_10)):
    Year_10[i] = int(Year_10[i])

# %%
#Printing after conversion

Year_10
# Out:
# [2018,
#  2017,
#  2020,
#  1998,
#  2008,
#  2006,
#  2015,
#  2013,
#  2006,
#  2015,
#  2016,
#  2010,
#  2021,
#  2015,
#  2014,
#  2017,
#  2016,
#  2016,
#  2013,
#  2014,
#  2015,
#  2009,
#  2017,
#  2013,
#  2019,
#  2009,
#  2015,
#  2017,
#  2003,
#  2011,
#  2004,
#  2015,
#  2018,
#  2018,
#  2011,
#  2014,
#  2012,
#  2014,
#  2017,
#  2010,
#  2011,
#  2018,
#  2019,
#  2007,
#  2021,
#  2017,
#  2020,
#  2020,
#  2018,
#  2010,
#  2019,
#  2015,
#  2019,
#  2001,
#  2013,
#  2009,
#  2020,
#  2008,
#  2009,
#  2010,
#  2008,
#  2009,
#  2012,
#  2012,
#  2011,
#  2009,
#  2016,
#  2004,
#  2016,
#  2018,
#  2018,
#  2008,
#  2012,
#  2003,
#  2003,
#  2011,
#  2005,
#  2015,
#  2012,
#  2016,
#  2013,
#  2001,
#  2019,
#  2015,
#  2015,
#  2013,
#  2016,
#  2012,
#  2019,
#  2007,
#  2014,
#  2014,
#  2016,
#  2000,
#  2020,
#  2020,
#  2015,
#  2018,
#  2010,
#  2010,
#  2012,
#  2017,
#  2017,
#  2014,
#  2013,
#  2016,
#  2016,
#  2014,
#  2014,
#  2020,
#  2017,
# ...

# %%
#Fetching data from olx for Km used, Company, Location, Date of posting

for k10 in driver10.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[1]"):
    Km_10.append(k10.text.split('-')[1])
for c10 in driver10.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[2]"):
    Company_10.append(c10.text)
for l10 in driver10.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]"):
    Location_10.append(l10.text)
for d10 in driver10.find_elements_by_xpath("//*[@id='container']/main/div/div/section/div/div/div[5]/div[2]/div/div[2]/ul/li/a/div[1]/div[2]/div[3]/span"):
    Date_10.append(d10.text)

# %%
#Making a dataframe named Cars storing 500 data into that

CARS10=pd.DataFrame({})
CARS10['PRICE']=Price_10[0:500]
CARS10['YEAR']=Year_10[0:500]
CARS10['KM']=Km_10[0:500]
CARS10['COMPANY']=Company_10[0:500]
CARS10['LOCATION']=Location_10[0:500]
CARS10['POSTED-DATE']=Date_10[0:500]

# %%
#Printing the dataframe

CARS10
# Out:
#         PRICE  YEAR           KM                    COMPANY  \
# 0      645000  2018    41,250 km       Maruti Suzuki Baleno
# 1      725000  2017    82,000 km  Maruti Suzuki Swift Dzire
# 2    13500000  2020     5,005 km               BMW 8 Series
# 3       35000  1998    50,000 km          Maruti Suzuki 800
# 4      185000  2008   141,000 km        Maruti Suzuki Swift
# ..        ...   ...          ...                        ...
# 495    135000  2010    61,314 km             Chevrolet Beat
# 496     61000  2000    95,000 km      Maruti Suzuki Wagon R
# 497   1250000  2013   130,000 km            Toyota Fortuner
# 498    640000  2017    37,000 km       Maruti Suzuki Baleno
# 499   2600000  2017    56,000 km                    Audi Q3
#
#                     LOCATION POSTED-DATE
# 0            Kowdiar\nJan 03      Jan 03
# 1    Changubetty\n5 days ago  5 days ago
# 2        Companypadi\nJan 12      Jan 12
# 3          Pazhakutty\nToday       Today
# ...

# %%
#Gwtting the information about the dataset

CARS10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PRICE        500 non-null    int64
#  1   YEAR         500 non-null    int64
#  2   KM           500 non-null    object
#  3   COMPANY      500 non-null    object
#  4   LOCATION     500 non-null    object
#  5   POSTED-DATE  500 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 23.6+ KB

# %%
driver10.close()

# %% [markdown]
# # 5497 IN TOTAL HAS BEEN NOW SCRAPED FROM THE WEBSITE

# %%
#Saving all the fileS into csv format that we have scraped in our all parts

df=CARS.to_csv('CARS-FILE1.csv')
df2=CARS2.to_csv('CARS-FILE2.csv')
df3=CARS3.to_csv('CARS-FILE3.csv')
df4=CARS4.to_csv('CARS-FILE4.csv')
df5=CARS5.to_csv('CARS-FILE5.csv')
df6=CARS6.to_csv('CARS-FILE6.csv')
df7=CARS7.to_csv('CARS-FILE7.csv')
df8=CARS8.to_csv('CARS-FILE8.csv')
df9=CARS9.to_csv('CARS-FILE9.csv')

# %%
df01=CARS10.to_csv('CARS-FILE01.csv')

# %% [markdown]
# # WE HAVE CREATED THE CSV FILES OF ALL THE PARTS

# %%
# !pip install glob
# Out:
# ERROR: Could not find a version that satisfies the requirement glob (from versions: none)
# ERROR: No matching distribution found for glob

# %%
#Importing pandas & glob

import pandas as pd
from glob import glob

# %%
#Storing our directory of our file into files

files = sorted(glob('E:/TEJ/FLIPROBO/CAR-PRICE/DATAA/CARS-FILE*.csv'))
files
# Out:
# ['E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE01.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE1.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE10.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE2.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE3.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE4.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE5.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE6.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE7.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE8.csv',
#  'E:/TEJ/FLIPROBO/CAR-PRICE/DATAA\\CARS-FILE9.csv']

# %% [markdown]
# # NOW WE WILL MERGE THE DATA WITH THE HELP OF CONCAT FUNCTION

# %%
#Using concat function & saving all the 6 files into one with the help of for loop

merge_data = pd.concat(pd.read_csv(datafile).assign(soucefilename = datafile)
                      for datafile in files)

# %%
#Printing the merged data that we have created from 6 different files

merge_data
# Out:
#      Unnamed: 0       PRICE    YEAR           KM                    COMPANY  \
# 0             0    645000.0  2018.0    41,250 km       Maruti Suzuki Baleno
# 1             1    725000.0  2017.0    82,000 km  Maruti Suzuki Swift Dzire
# 2             2  13500000.0  2020.0     5,005 km               BMW 8 Series
# 3             3     35000.0  1998.0    50,000 km          Maruti Suzuki 800
# 4             4    185000.0  2008.0   141,000 km        Maruti Suzuki Swift
# ..          ...         ...     ...          ...                        ...
# 495         495   1390000.0  2014.0    58,000 km                    Audi Q3
# 496         496    280000.0  2012.0    80,000 km       Maruti Suzuki Ertiga
# 497         497     45000.0  2006.0   118,000 km     Maruti Suzuki Alto 800
# 498         498    325000.0  2017.0    88,000 km              Hyundai Xcent
# 499         499    700000.0  2018.0    73,000 km         Hyundai i20 Active
#
#                     LOCATION POSTED-DATE  \
# ...

# %% [markdown]
# # NOW HERE WE HAVE ADDED ALL THE FILES IN ONE NOW WE WILL SAVE IT IN ONE CSV FILE

# %%
#Now we will save the entire file into one csv file 

merge_data.to_csv('CAR-PRICE-DATA-FINAL.csv')

# %%
#END
